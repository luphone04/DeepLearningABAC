# %%
# Checkpoint the weights when validation accuracy improves
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
seed = 42
tf.random.set_seed(seed)
# load pima indians dataset
dataset = np.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=10, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.67323, saving model to weights-improvement-01-0.67.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_accuracy did not improve from 0.67323
#
# Epoch 3: val_accuracy improved from 0.67323 to 0.68898, saving model to weights-improvement-03-0.69.hdf5
#
# Epoch 4: val_accuracy did not improve from 0.68898
#
# Epoch 5: val_accuracy did not improve from 0.68898
#
# Epoch 6: val_accuracy did not improve from 0.68898
#
# Epoch 7: val_accuracy improved from 0.68898 to 0.71260, saving model to weights-improvement-07-0.71.hdf5
#
# Epoch 8: val_accuracy did not improve from 0.71260
#
# Epoch 9: val_accuracy did not improve from 0.71260
#
# Epoch 10: val_accuracy improved from 0.71260 to 0.72441, saving model to weights-improvement-10-0.72.hdf5

# %%
# Checkpoint the weights for best model on validation accuracy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.40945, saving model to weights.best.hdf5
#
# Epoch 2: val_accuracy improved from 0.40945 to 0.69291, saving model to weights.best.hdf5
#
# Epoch 3: val_accuracy did not improve from 0.69291
#
# Epoch 4: val_accuracy did not improve from 0.69291
#
# Epoch 5: val_accuracy did not improve from 0.69291
#
# Epoch 6: val_accuracy did not improve from 0.69291
#
# Epoch 7: val_accuracy did not improve from 0.69291
#
# Epoch 8: val_accuracy did not improve from 0.69291
#
# Epoch 9: val_accuracy did not improve from 0.69291
#
# Epoch 10: val_accuracy did not improve from 0.69291
#
# Epoch 11: val_accuracy did not improve from 0.69291
#
# Epoch 12: val_accuracy did not improve from 0.69291
#
# Epoch 13: val_accuracy did not improve from 0.69291
#
# Epoch 14: val_accuracy did not improve from 0.69291
#
# Epoch 15: val_accuracy did not improve from 0.69291
#
# Epoch 16: val_accuracy did not improve from 0.69291
#
# Epoch 17: val_accuracy did not improve from 0.69291
#
# Epoch 18: val_accuracy did not improve from 0.69291
#
# Epoch 19: val_accuracy did not improve from 0.69291
#
# Epoch 20: val_accuracy did not improve from 0.69291
#
# Epoch 21: val_accuracy did not improve from 0.69291
#
# Epoch 22: val_accuracy did not improve from 0.69291
#
# Epoch 23: val_accuracy did not improve from 0.69291
#
# Epoch 24: val_accuracy did not improve from 0.69291
#
# Epoch 25: val_accuracy improved from 0.69291 to 0.69685, saving model to weights.best.hdf5
#
# Epoch 26: val_accuracy did not improve from 0.69685
#
# Epoch 27: val_accuracy did not improve from 0.69685
#
# Epoch 28: val_accuracy did not improve from 0.69685
#
# Epoch 29: val_accuracy did not improve from 0.69685
#
# Epoch 30: val_accuracy did not improve from 0.69685
#
# Epoch 31: val_accuracy did not improve from 0.69685
#
# Epoch 32: val_accuracy did not improve from 0.69685
#
# Epoch 33: val_accuracy did not improve from 0.69685
#
# Epoch 34: val_accuracy did not improve from 0.69685
#
# Epoch 35: val_accuracy did not improve from 0.69685
#
# Epoch 36: val_accuracy did not improve from 0.69685
#
# Epoch 37: val_accuracy did not improve from 0.69685
#
# Epoch 38: val_accuracy did not improve from 0.69685
#
# Epoch 39: val_accuracy did not improve from 0.69685
#
# Epoch 40: val_accuracy did not improve from 0.69685
#
# Epoch 41: val_accuracy did not improve from 0.69685
#
# Epoch 42: val_accuracy did not improve from 0.69685
#
# Epoch 43: val_accuracy did not improve from 0.69685
#
# Epoch 44: val_accuracy did not improve from 0.69685
#
# Epoch 45: val_accuracy did not improve from 0.69685
#
# Epoch 46: val_accuracy improved from 0.69685 to 0.70079, saving model to weights.best.hdf5
#
# Epoch 47: val_accuracy did not improve from 0.70079
#
# Epoch 48: val_accuracy did not improve from 0.70079
#
# Epoch 49: val_accuracy did not improve from 0.70079
#
# Epoch 50: val_accuracy improved from 0.70079 to 0.70472, saving model to weights.best.hdf5
#
# Epoch 51: val_accuracy improved from 0.70472 to 0.71260, saving model to weights.best.hdf5
#
# Epoch 52: val_accuracy did not improve from 0.71260
#
# Epoch 53: val_accuracy did not improve from 0.71260
#
# Epoch 54: val_accuracy did not improve from 0.71260
#
# Epoch 55: val_accuracy did not improve from 0.71260
#
# Epoch 56: val_accuracy did not improve from 0.71260
#
# Epoch 57: val_accuracy did not improve from 0.71260
#
# Epoch 58: val_accuracy did not improve from 0.71260
#
# Epoch 59: val_accuracy did not improve from 0.71260
#
# Epoch 60: val_accuracy did not improve from 0.71260
#
# Epoch 61: val_accuracy did not improve from 0.71260
#
# Epoch 62: val_accuracy did not improve from 0.71260
#
# Epoch 63: val_accuracy did not improve from 0.71260
#
# Epoch 64: val_accuracy did not improve from 0.71260
#
# Epoch 65: val_accuracy did not improve from 0.71260
#
# Epoch 66: val_accuracy did not improve from 0.71260
#
# Epoch 67: val_accuracy did not improve from 0.71260
#
# Epoch 68: val_accuracy did not improve from 0.71260
#
# Epoch 69: val_accuracy did not improve from 0.71260
#
# Epoch 70: val_accuracy did not improve from 0.71260
#
# Epoch 71: val_accuracy did not improve from 0.71260
#
# Epoch 72: val_accuracy did not improve from 0.71260
#
# Epoch 73: val_accuracy did not improve from 0.71260
#
# Epoch 74: val_accuracy did not improve from 0.71260
#
# Epoch 75: val_accuracy did not improve from 0.71260
#
# Epoch 76: val_accuracy did not improve from 0.71260
#
# Epoch 77: val_accuracy did not improve from 0.71260
#
# Epoch 78: val_accuracy did not improve from 0.71260
#
# Epoch 79: val_accuracy improved from 0.71260 to 0.72835, saving model to weights.best.hdf5
#
# Epoch 80: val_accuracy did not improve from 0.72835
#
# Epoch 81: val_accuracy did not improve from 0.72835
#
# Epoch 82: val_accuracy did not improve from 0.72835
#
# Epoch 83: val_accuracy did not improve from 0.72835
#
# Epoch 84: val_accuracy did not improve from 0.72835
#
# Epoch 85: val_accuracy did not improve from 0.72835
#
# Epoch 86: val_accuracy did not improve from 0.72835
#
# Epoch 87: val_accuracy did not improve from 0.72835
#
# Epoch 88: val_accuracy did not improve from 0.72835
#
# Epoch 89: val_accuracy did not improve from 0.72835
#
# Epoch 90: val_accuracy did not improve from 0.72835
#
# Epoch 91: val_accuracy did not improve from 0.72835
#
# Epoch 92: val_accuracy did not improve from 0.72835
#
# Epoch 93: val_accuracy did not improve from 0.72835
#
# Epoch 94: val_accuracy did not improve from 0.72835
#
# Epoch 95: val_accuracy did not improve from 0.72835
#
# Epoch 96: val_accuracy did not improve from 0.72835
#
# Epoch 97: val_accuracy did not improve from 0.72835
#
# Epoch 98: val_accuracy did not improve from 0.72835
#
# Epoch 99: val_accuracy did not improve from 0.72835
#
# Epoch 100: val_accuracy did not improve from 0.72835
#
# Epoch 101: val_accuracy did not improve from 0.72835
#
# Epoch 102: val_accuracy did not improve from 0.72835
#
# Epoch 103: val_accuracy did not improve from 0.72835
#
# Epoch 104: val_accuracy did not improve from 0.72835
#
# Epoch 105: val_accuracy did not improve from 0.72835
#
# Epoch 106: val_accuracy did not improve from 0.72835
#
# Epoch 107: val_accuracy did not improve from 0.72835
#
# Epoch 108: val_accuracy did not improve from 0.72835
#
# Epoch 109: val_accuracy did not improve from 0.72835
#
# Epoch 110: val_accuracy did not improve from 0.72835
#
# Epoch 111: val_accuracy did not improve from 0.72835
#
# Epoch 112: val_accuracy did not improve from 0.72835
#
# Epoch 113: val_accuracy did not improve from 0.72835
#
# Epoch 114: val_accuracy did not improve from 0.72835
#
# Epoch 115: val_accuracy did not improve from 0.72835
#
# Epoch 116: val_accuracy did not improve from 0.72835
#
# Epoch 117: val_accuracy did not improve from 0.72835
#
# Epoch 118: val_accuracy did not improve from 0.72835
#
# Epoch 119: val_accuracy did not improve from 0.72835
#
# Epoch 120: val_accuracy did not improve from 0.72835
#
# Epoch 121: val_accuracy improved from 0.72835 to 0.73622, saving model to weights.best.hdf5
#
# Epoch 122: val_accuracy improved from 0.73622 to 0.74016, saving model to weights.best.hdf5
#
# Epoch 123: val_accuracy did not improve from 0.74016
#
# Epoch 124: val_accuracy did not improve from 0.74016
#
# Epoch 125: val_accuracy did not improve from 0.74016
#
# Epoch 126: val_accuracy did not improve from 0.74016
#
# Epoch 127: val_accuracy did not improve from 0.74016
#
# Epoch 128: val_accuracy did not improve from 0.74016
#
# Epoch 129: val_accuracy did not improve from 0.74016
#
# Epoch 130: val_accuracy did not improve from 0.74016
#
# Epoch 131: val_accuracy did not improve from 0.74016
#
# Epoch 132: val_accuracy did not improve from 0.74016
#
# Epoch 133: val_accuracy did not improve from 0.74016
#
# Epoch 134: val_accuracy did not improve from 0.74016
#
# Epoch 135: val_accuracy did not improve from 0.74016
#
# Epoch 136: val_accuracy did not improve from 0.74016
#
# Epoch 137: val_accuracy did not improve from 0.74016
#
# Epoch 138: val_accuracy did not improve from 0.74016
#
# Epoch 139: val_accuracy did not improve from 0.74016
#
# Epoch 140: val_accuracy did not improve from 0.74016
#
# Epoch 141: val_accuracy did not improve from 0.74016
#
# Epoch 142: val_accuracy did not improve from 0.74016
#
# Epoch 143: val_accuracy did not improve from 0.74016
#
# Epoch 144: val_accuracy did not improve from 0.74016
#
# Epoch 145: val_accuracy did not improve from 0.74016
#
# Epoch 146: val_accuracy did not improve from 0.74016
#
# Epoch 147: val_accuracy did not improve from 0.74016
#
# Epoch 148: val_accuracy did not improve from 0.74016
#
# Epoch 149: val_accuracy did not improve from 0.74016
#
# Epoch 150: val_accuracy did not improve from 0.74016

# %%
# Checkpoint the weights for best model on validation accuracy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_accuracy', patience=5)
callbacks_list = [checkpoint, es]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.55118, saving model to weights.best.hdf5
#
# Epoch 2: val_accuracy improved from 0.55118 to 0.62992, saving model to weights.best.hdf5
#
# Epoch 3: val_accuracy improved from 0.62992 to 0.66535, saving model to weights.best.hdf5
#
# Epoch 4: val_accuracy improved from 0.66535 to 0.66929, saving model to weights.best.hdf5
#
# Epoch 5: val_accuracy improved from 0.66929 to 0.68110, saving model to weights.best.hdf5
#
# Epoch 6: val_accuracy did not improve from 0.68110
#
# Epoch 7: val_accuracy did not improve from 0.68110
#
# Epoch 8: val_accuracy did not improve from 0.68110
#
# Epoch 9: val_accuracy did not improve from 0.68110
#
# Epoch 10: val_accuracy improved from 0.68110 to 0.68898, saving model to weights.best.hdf5
#
# Epoch 11: val_accuracy did not improve from 0.68898
#
# Epoch 12: val_accuracy did not improve from 0.68898
#
# Epoch 13: val_accuracy did not improve from 0.68898
#
# Epoch 14: val_accuracy did not improve from 0.68898
#
# Epoch 15: val_accuracy did not improve from 0.68898

# %%
# How to load and use weights from a checkpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# load weights
model.load_weights("weights.best.hdf5")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Created model and loaded weights from file
# accuracy: 67.71%
